# %%
import pathlib

import pandas as pd
import tensorflow as tf

# %%
df_dir = pathlib.Path(pathlib.Path.cwd() / '../data/train_label.csv')
labels = pd.read_csv(df_dir)
labels = labels.set_index("ID")
classes = sorted(labels["Label"].unique())

# %%
seed = 123
batch_size = 32
image_height = 512
image_width = 512
data_dir = pathlib.Path(pathlib.Path.cwd() / '../data/train_image/train_image/')

image_ds = tf.data.Dataset.list_files(str(data_dir.resolve() / "*.png"), shuffle=False)
image_count = len(image_ds)
image_ds = image_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
def get_label(file_path):
    file_name = tf.strings.split(file_path, pathlib.os.sep)[-1]
    file_id = tf.strings.split(file_name, ".")[-2]
    label_name = tf.gather_nd(labels, [tf.strings.to_number(file_id, out_type=tf.dtypes.int32)])
    return tf.argmax(label_name == classes)

def decode_image(image_file):
    image_data = tf.image.decode_jpeg(image_file, channels=3)
    return tf.image.resize(image_data, [image_height, image_width])

def process_path(file_path):
    label_name = get_label(file_path)
    image_file = tf.io.read_file(file_path)
    image_data = decode_image(image_file)
    return image_data, label_name

for image, label in image_ds.map(process_path).take(10):
    print(label.numpy())
# Out:
# 1
# 1
# 2
# 2
# 1
# 0
# 0
# 0
# 2
# 1

# %%
val_size = int(image_count * 0.2)
train_ds = image_ds.skip(val_size)
val_ds = image_ds.take(val_size)

train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %%
def configure_for_performance(ds):
    ds = ds.cache()
    ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
import matplotlib.pyplot as plt

image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    plt.title(classes[label])
    plt.axis("off")

# %%
import numpy as np

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.003921569 1.0

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
num_classes = 3

model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes)
])

model.compile(
    optimizer='adam',
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %%
model.build((batch_size, image_height, image_width, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_1 (Rescaling)      (32, 512, 512, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (32, 510, 510, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 255, 255, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 253, 253, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 126, 126, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 124, 124, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (32, 62, 62, 32)          0
# ...

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 30/30 [==============================] - 103s 3s/step - loss: 1.4192 - accuracy: 0.6481 - val_loss: 0.5942 - val_accuracy: 0.7112
# Epoch 2/3
# 30/30 [==============================] - 104s 3s/step - loss: 0.4048 - accuracy: 0.8047 - val_loss: 0.4746 - val_accuracy: 0.7586
# Epoch 3/3
# 30/30 [==============================] - 100s 3s/step - loss: 0.3225 - accuracy: 0.8584 - val_loss: 0.4590 - val_accuracy: 0.7716
